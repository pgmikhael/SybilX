# %%
# !pip install itk-twoprojectionregistration
# Out:
# ...
#      |████████████████████████████████| 2.0 MB 7.5 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 54.5 MB 16 kB/s s eta 0:00:01
# ...
#      |████████████████████████████████| 70.7 MB 341 bytes/s a 0:00:01     |██████████                      | 22.1 MB 34.9 MB/s eta 0:00:02     |█████████████████████████       | 55.0 MB 31.8 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 95.3 MB 9.8 kB/s  eta 0:00:01    |██▊                             | 8.2 MB 28.1 MB/s eta 0:00:04     |█████▉                          | 17.4 MB 28.1 MB/s eta 0:00:03     |██████████████████████████████  | 89.3 MB 46.5 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 15.0 MB 49 kB/s s eta 0:00:01    |██████▊                         | 3.2 MB 26.7 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 20.3 MB 45 kB/s s eta 0:00:01
# ...
#      |████████████████████████████████| 16.6 MB 9.0 kB/s  eta 0:00:01    |▊                               | 358 kB 29.3 MB/s eta 0:00:01
# ...

# %%
import itk

# %%
dir(itk)
# Out:
# ['AbortCheckEvent',
#  'AbortEvent',
#  'AbsImageFilter',
#  'AbsoluteValueDifferenceImageFilter',
#  'AccumulateImageFilter',
#  'AcosImageFilter',
#  'AdaptiveEqualizationHistogram',
#  'AdaptiveHistogramEqualizationImageFilter',
#  'AddImageFilter',
#  'AdditiveGaussianNoiseImageFilter',
#  'AffineTransform',
#  'AggregateLabelMapFilter',
#  'AmoebaOptimizer',
#  'AndImageFilter',
#  'AnisotropicDiffusionImageFilter',
#  'AnisotropicFourthOrderLevelSetImageFilter',
#  'AnnulusOperator',
#  'AntiAliasBinaryImageFilter',
#  'AnyEvent',
#  'ApproximateSignedDistanceMapImageFilter',
#  'ArchetypeSeriesFileNames',
#  'Array',
#  'Array2D',
#  'ArrowSpatialObject',
#  'AsinImageFilter',
#  'Atan2ImageFilter',
#  'AtanImageFilter',
#  'AuthalicMatrixCoefficients',
#  'AutoCropLabelMapFilter',
#  'AutoProgressTypes',
#  'AzimuthElevationToCartesianTransform',
#  'B',
#  'BMPImageIO',
#  'BMPImageIOFactory',
#  'BSplineBaseTransform',
#  'BSplineDecompositionImageFilter',
# ...

# %%
itk.SiddonJacobsRayCastInterpolateImageFunction
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-4957f9c6e89b> in <module>
# ----> 1 itk.SiddonJacobsRayCastInterpolateImageFunction
#
# /Mounts/rbg-storage1/users/itamarc/miniconda3/envs/playground/lib/python3.8/site-packages/itk/support/lazy.py in __getattribute__(self, attr)
#     134                     for k, v in namespace.items():
#     135                         setattr(self, k, v)
# --> 136                     value = namespace[attr]
#     137                 else:  # one of the other threads that had been blocking
#     138                     # waiting for first thread to complete. Now the
#
# KeyError: 'SiddonJacobsRayCastInterpolateImageFunction'
